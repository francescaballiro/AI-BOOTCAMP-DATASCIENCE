# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from statsmodels.tsa.seasonal import seasonal_decompose

# %% [markdown]
# # HOMEWORK:

# %% [markdown]
# ## ESERCIZIO 1
# Given the dataframe attached "df3.csv", which columns contributed to creating the column "f"?

# %%
df = pd.read_csv('df3.csv')
print(df.describe())
# Out:
#         Unnamed: 0             a             b             c             d  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    4999.50000     19.990517      8.432936     49.997172      0.500000
# std     2886.89568      1.002156     99.349412      1.398425      0.500025
# min        0.00000     15.952462   -349.948177     44.976797      0.000000
# 25%     2499.75000     19.310551    -58.813051     49.041371      0.000000
# 50%     4999.50000     19.992343      9.235839     50.000849      0.500000
# 75%     7499.25000     20.659627     75.598769     50.927786      1.000000
# max     9999.00000     23.639378    369.157557     55.774907      1.000000
#
#                   x             y        z             h             g  \
# count  10000.000000  10000.000000  10000.0  10000.000000  10000.000000
# mean      -0.002568      8.435505      0.0      0.500000     49.999740
# std        0.988702     99.354922      0.0      0.500025      0.998051
# min       -3.891829   -350.306688      0.0      0.000000     46.359629
# 25%       -0.664353    -59.078548      0.0      0.000000     49.328221
# 50%       -0.003790      9.444036      0.0      0.500000     50.007912
# 75%        0.663694     75.779854      0.0      1.000000     50.674980
# max        3.504197    369.721812      0.0      1.000000     54.009690
#
#                   f
# count  10000.000000
# mean     241.631775
# std      269.395359
# min     -368.620901
# 25%       -9.235237
# 50%      245.476066
# 75%      491.500945
# max      857.753122

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'a', 'b', 'c', 'd', 'x', 'y', 'z', 'h', 'g', 'f'], dtype='object')

# %%
corr_matrix = df.corr()
print(corr_matrix['f'])
# Out:
# Unnamed: 0   -0.007615
# a            -0.006081
# b            -0.370958
# c             0.019905
# d             0.928932
# x            -0.002183
# y            -0.370916
# z                  NaN
# h            -0.008912
# g             0.030053
# f             1.000000
# Name: f, dtype: float64

# %%
cols = ['a', 'b', 'c', 'd', 'x', 'y', 'h', 'g', 'f']
corr = df[cols].corr()
plt.figure(figsize=(12, 12))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.suptitle("Correlation Heatmap")
plt.show()

# %% [markdown]
# Dal grafico superiore vedo che la colonna 'f' ha una corellazione con la colonna 'd' e in misura minore anche con le colonne 'b' e 'y'

# %%
# creo una heatmap solo con le colonne che hanno una correlazione con 'f'
cols = ['d', 'b', 'y', 'f']
corr = df[cols].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# posso inoltre notare come le colonne 'b' e 'y' abbiano una correlazione molto forte, probabilmente una delle due è stata creata partendo dall'altra

# %% [markdown]
# ## ESERCIZIO 2
# Plot the function y = 1/x between -10 and 10

# %%
x = np.linspace(-10, 10, 100)
y = (1/x)
plt.figure(figsize=(8,4))
plt.plot(x, y, label='y = 1/x', color='black')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = f(x)')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## ESERCIZIO 3
# Recreate the following heatmaps

# %% [markdown]
# FIGURA 1

# %%
# Generate simulation data for heatmap
x_vals = np.linspace(-5, 5, 50)
y_vals = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x_vals, y_vals) #griglia di valori di x, y
Z = X * Y  # z è la funzione che dipende da x e y

# Convert to DataFrame
df_simulation = pd.DataFrame({'x': X.ravel(), 'y': Y.ravel(), 'z': Z.ravel()})

# Pivot the data for heatmap
heatmap_data = df_simulation.pivot(index='y', columns='x', values='z')

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, cmap='coolwarm', annot=False)
plt.title('Heatmap of z as function of x and y')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# FIGURA 2

# %%
# Generate simulation data for heatmap
x_vals = np.linspace(-5, 5, 50)
y_vals = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x_vals, y_vals) #griglia di valori di x, y
Z = (X**2) + (Y**2)  # z è la funzione che dipende da x e y

# Convert to DataFrame
df_simulation = pd.DataFrame({'x': X.ravel(), 'y': Y.ravel(), 'z': Z.ravel()})

# Pivot the data for heatmap
heatmap_data = df_simulation.pivot(index='y', columns='x', values='z')

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, cmap='coolwarm', annot=False)
plt.title('Heatmap of z as function of x and y')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# FIGURA 3

# %%
# Generate simulation data for heatmap
x_vals = np.linspace(-5, 5, 50)
y_vals = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x_vals, y_vals) #griglia di valori di x, y
Z = (X**2) + Y # z è la funzione che dipende da x e y

# Convert to DataFrame
df_simulation = pd.DataFrame({'x': X.ravel(), 'y': Y.ravel(), 'z': Z.ravel()})

# Pivot the data for heatmap
heatmap_data = df_simulation.pivot(index='y', columns='x', values='z')

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, cmap='coolwarm', annot=False)
plt.title('Heatmap of z as function of x and y')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
